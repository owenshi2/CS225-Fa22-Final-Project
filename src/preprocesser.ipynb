# %%
import pandas as pd
df = pd.read_csv('./entry/routes.csv')
df
# Out:
#       airline airline ID  source airport  source airport id  \
# 0          2B        410             AER               2965
# 1          2B        410             ASF               2966
# 2          2B        410             ASF               2966
# 3          2B        410             CEK               2968
# 4          2B        410             CEK               2968
# ...       ...        ...             ...                ...
# 67658      ZL       4178             WYA               6334
# 67659      ZM      19016             DME               4029
# 67660      ZM      19016             FRU               2912
# 67661      ZM      19016             FRU               2912
# 67662      ZM      19016             OSS               2913
#
#        destination apirport  destination airport id  codeshare   stops  \
# 0                       KZN                    2990        NaN       0
# 1                       KZN                    2990        NaN       0
# ...

# %%
df.filter(items=["airline" ," source airport", " destination apirport"])
# Out:
#       airline  source airport  destination apirport
# 0          2B             AER                   KZN
# 1          2B             ASF                   KZN
# 2          2B             ASF                   MRV
# 3          2B             CEK                   KZN
# 4          2B             CEK                   OVB
# ...       ...             ...                   ...
# 67658      ZL             WYA                   ADL
# 67659      ZM             DME                   FRU
# 67660      ZM             FRU                   DME
# 67661      ZM             FRU                   OSS
# 67662      ZM             OSS                   FRU
#
# [67663 rows x 3 columns]

# %%
codes = pd.read_csv('./entry/airport-codes.csv')
codes.head()
# Out:
#   ident           type                                name  elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport          11.0
# 1  00AA  small_airport                Aero B Ranch Airport        3435.0
# 2  00AK  small_airport                        Lowell Field         450.0
# 3  00AL  small_airport                        Epps Airpark         820.0
# 4  00AR         closed  Newport Hospital & Clinic Heliport         237.0
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0       NaN          US      US-PA      Bensalem      00A       NaN
# 1       NaN          US      US-KS         Leoti     00AA       NaN
# 2       NaN          US      US-AK  Anchor Point     00AK       NaN
# 3       NaN          US      US-AL       Harvest     00AL       NaN
# 4       NaN          US      US-AR       Newport      NaN       NaN
#
#   local_code                            coordinates
# 0        00A     40.07080078125, -74.93360137939453
# ...

# %%
codes = codes.dropna(subset=['iso_country', 'iata_code'])
codes
# Out:
#       ident            type                         name  elevation_ft  \
# 223     03N   small_airport               Utirik Airport           4.0
# 440    07FA   small_airport      Ocean Reef Club Airport           8.0
# 594     0AK   small_airport        Pilot Station Airport         305.0
# 673    0CO2   small_airport        Crested Butte Airpark        8980.0
# 1088   0TE7   small_airport            LBJ Ranch Airport        1515.0
# ...     ...             ...                          ...           ...
# 55104  ZYTL   large_airport           Zhoushuizi Airport         107.0
# 55105  ZYTN  medium_airport    Tonghua Sanyuanpu Airport        1200.0
# 55106  ZYTX   large_airport              Taoxian Airport         198.0
# 55107  ZYYJ  medium_airport  Yanji Chaoyangchuan Airport         624.0
# 55108  ZYYK  medium_airport        Yingkou Lanqi Airport           0.0
#
#       continent iso_country iso_region   municipality gps_code iata_code  \
# ...

# %%
filter_codes  = codes[codes.iso_country.isin(cities.iso2)]
filter_codes
# Out:
#       ident           type                           name  elevation_ft  \
# 223     03N  small_airport                 Utirik Airport           4.0
# 10375   ADC  small_airport              Andakombe Airport        3600.0
# 10405   AEK  small_airport                  Aseki Airport        4106.0
# 10465   AIE  small_airport                  Aiome Airport         350.0
# 10466   AIH  small_airport                Aiambak Airport          90.0
# ...     ...            ...                            ...           ...
# 53904  YNMN  small_airport               New Moon Airport        1099.0
# 53994  YPDA  small_airport               Parndana Airport         545.0
# 54196  YSTI  seaplane_base  Stephens Island Seaplane Base           0.0
# 54204  YSVP  small_airport          Silver Plains Airport          48.0
# 54816   ZEN  small_airport                  Zenag Airport        3200.0
#
#       continent iso_country iso_region     municipality gps_code iata_code  \
# ...
