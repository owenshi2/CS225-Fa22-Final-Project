# %%
import pandas as pd
routes = pd.read_csv('./entry/routes.csv')
routes
# Out:
#       airline airline ID  source airport  source airport id  \
# 0          2B        410             AER               2965
# 1          2B        410             ASF               2966
# 2          2B        410             ASF               2966
# 3          2B        410             CEK               2968
# 4          2B        410             CEK               2968
# ...       ...        ...             ...                ...
# 67658      ZL       4178             WYA               6334
# 67659      ZM      19016             DME               4029
# 67660      ZM      19016             FRU               2912
# 67661      ZM      19016             FRU               2912
# 67662      ZM      19016             OSS               2913
#
#        destination apirport  destination airport id  codeshare   stops  \
# 0                       KZN                    2990        NaN       0
# 1                       KZN                    2990        NaN       0
# ...

# %%
routes = routes.filter(items=["airline" ," source airport", " destination apirport"])
routes
# Out:
#       airline  source airport  destination apirport
# 0          2B             AER                   KZN
# 1          2B             ASF                   KZN
# 2          2B             ASF                   MRV
# 3          2B             CEK                   KZN
# 4          2B             CEK                   OVB
# ...       ...             ...                   ...
# 67658      ZL             WYA                   ADL
# 67659      ZM             DME                   FRU
# 67660      ZM             FRU                   DME
# 67661      ZM             FRU                   OSS
# 67662      ZM             OSS                   FRU
#
# [67663 rows x 3 columns]

# %%
codes = pd.read_csv('./entry/airport-codes.csv')
codes.head()
# Out:
#   ident           type                                name  elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport          11.0
# 1  00AA  small_airport                Aero B Ranch Airport        3435.0
# 2  00AK  small_airport                        Lowell Field         450.0
# 3  00AL  small_airport                        Epps Airpark         820.0
# 4  00AR         closed  Newport Hospital & Clinic Heliport         237.0
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0       NaN          US      US-PA      Bensalem      00A       NaN
# 1       NaN          US      US-KS         Leoti     00AA       NaN
# 2       NaN          US      US-AK  Anchor Point     00AK       NaN
# 3       NaN          US      US-AL       Harvest     00AL       NaN
# 4       NaN          US      US-AR       Newport      NaN       NaN
#
#   local_code                            coordinates
# 0        00A     40.07080078125, -74.93360137939453
# ...

# %%
codes = codes.dropna(subset=['iso_country', 'iata_code', "municipality"])
codes = codes.filter(items=["iso_country", "municipality", "iata_code"])
codes
# Out:
#       iso_country   municipality iata_code
# 223            MH  Utirik Island       UTK
# 440            US      Key Largo       OCA
# 594            US  Pilot Station       PQS
# 673            US  Crested Butte       CSE
# 1088           US   Johnson City       JCY
# ...           ...            ...       ...
# 55104          CN         Dalian       DLC
# 55105          CN        Tonghua       TNH
# 55106          CN       Shenyang       SHE
# 55107          CN          Yanji       YNJ
# 55108          CN        Yingkou       YKH
#
# [8386 rows x 3 columns]

# %%
cities = pd.read_csv('./entry/worldcities.csv')
cities = cities.filter(items=["city_ascii" ,"population"])
cities.head()
# Out:
#   city_ascii  population
# 0      Tokyo  39105000.0
# 1    Jakarta  35362000.0
# 2      Delhi  31870000.0
# 3     Manila  23971000.0
# 4  Sao Paulo  22495000.0

# %%
combined = codes.merge(cities, how='inner', left_on='municipality', right_on='city_ascii')
combined = combined.drop(['municipality'], axis = 1)
combined
# Out:
#      iso_country iata_code    city_ascii  population
# 0             US       OCA     Key Largo      9952.0
# 1             US       KYL     Key Largo      9952.0
# 2             US       JCY  Johnson City    127571.0
# 3             US       JCY  Johnson City     14161.0
# 4             US       PMX        Palmer     21345.0
# ...          ...       ...           ...         ...
# 7717          CN       NDG       Qiqihar   5367003.0
# 7718          CN       DLC        Dalian   4480000.0
# 7719          CN       SHE      Shenyang   7208000.0
# 7720          CN       YNJ         Yanji    513072.0
# 7721          CN       YKH       Yingkou   2428534.0
#
# [7722 rows x 4 columns]

# %%
combined = combined.dropna()
combined = combined.drop_duplicates(subset=['city_ascii'])
combined
# Out:
#      iso_country iata_code    city_ascii  population
# 0             US       OCA     Key Largo      9952.0
# 2             US       JCY  Johnson City    127571.0
# 4             US       PMX        Palmer     21345.0
# 10            US       DRF         Kenai      7807.0
# 12            US       BDF      Bradford    293277.0
# ...          ...       ...           ...         ...
# 7717          CN       NDG       Qiqihar   5367003.0
# 7718          CN       DLC        Dalian   4480000.0
# 7719          CN       SHE      Shenyang   7208000.0
# 7720          CN       YNJ         Yanji    513072.0
# 7721          CN       YKH       Yingkou   2428534.0
#
# [3525 rows x 4 columns]

# %%
routes.to_csv('flight-paths.csv', index=False) 
combined.to_csv('cities-data.csv', index=False)
